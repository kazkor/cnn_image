# %% [markdown]
# # Imports

# %%
import tensorflow as tf

import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

from tensorflow import keras
from tensorflow.keras.layers import BatchNormalization
from sklearn.metrics import confusion_matrix
from collections import Counter
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

import itertools
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# # GPU

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
len(gpus)
# Out:
# 1

# %% [markdown]
# # Data Loading

# %%
#directory of the dataset
DATA_DIR = 'NWPU-nature' 

#size of the image (images will be resized to these sizes)
img_height = 128
img_width = 128

#size of the batch
batch_size = 32

# %%
data = tf.keras.utils.image_dataset_from_directory(
  DATA_DIR,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 7000 files belonging to 10 classes.
# Metal device set to: Apple M1
# 2023-03-13 16:30:47.740513: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-13 16:30:47.740536: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Classes in the dataset

# %%
class_names = data.class_names
num_classes = len(class_names)
print(class_names)
# Out:
# ['beach', 'chaparral', 'circular_farmland', 'desert', 'forest', 'island', 'lake', 'sea_ice', 'snowberg', 'terrace']

# %% [markdown]
# ### Size of the subsets

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)+1
test_size = int(len(data)*.1)+1

# %%
train = data.take(int(train_size))
val = data.skip(train_size).take(int(val_size))
test = data.skip(train_size+val_size).take(int(test_size))

print(f'Size of the training set: {len(train)*batch_size}')
print(f'Size of the validation set: {len(val)*batch_size}')
print(f'Size of the testing set: {len(test)*batch_size}')
# Out:
# Size of the training set: 4896
# Size of the validation set: 1408
# Size of the testing set: 704

# %% [markdown]
# ### Balance of the dataset
# Merging label batches to check balance of the dataset

# %%
to_flat = []
for batch in data.as_numpy_iterator():
    to_flat.append(batch[1])

flat_list = list(itertools.chain(*to_flat))
len(flat_list)
# Out:
# 2023-03-13 16:30:47.800037: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 7000

# %% [markdown]
# ### Plotting the number of instances
# (right now its equally distributed but it is not always the case)

# %%
g = sns.countplot(x=flat_list)
g.set_xticklabels(class_names)
g.set_title('Numbers of classes')
g.set_xticklabels(g.get_xticklabels(), rotation=45)
g.plot
# Out:
# <bound method Axes.plot of <Axes: title={'center': 'Numbers of classes'}, ylabel='count'>>

# %% [markdown]
# ### Shape of the images
# should be: img_width (128) x img_height (128) x RGB pixels values (3)

# %%
for image_batch, labels_batch in train:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 128, 128, 3)
# (32,)

# %% [markdown]
# ### Saving the shape to the variable to make code more flexible

# %%
shape = image_batch.shape[1:]
shape
# Out:
# TensorShape([128, 128, 3])

# %% [markdown]
# ### Plotting sample images

# %%
image_batch,label_batch= next(iter(train))

# %%
fig = plt.figure(figsize=(8, 8))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img = image_batch[i]/255
    fig.add_subplot(rows, columns, i)
    plt.title(class_names[int(label_batch[i])])
    plt.axis("off")
    plt.imshow(img)
plt.show()

# %%
AUTOTUNE = tf.data.AUTOTUNE
train= train.cache().prefetch(buffer_size=AUTOTUNE)
val = val.cache().prefetch(buffer_size=AUTOTUNE)
test = test.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = tf.keras.layers.Rescaling(scale=1./255)

# %% [markdown]
# # Model

# %%
model = tf.keras.Sequential([

  normalization_layer, 

  tf.keras.layers.Resizing(
  img_height,
  img_width,
  interpolation='bilinear',crop_to_aspect_ratio=True),

  tf.keras.layers.Conv2D(64, (3,3), 1, padding='same', activation='relu', input_shape=shape),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D((2,2)),
  
  tf.keras.layers.Conv2D(128, (3,3),1,padding='same', activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D((2,2)),  
  
  tf.keras.layers.Conv2D(128, (3,3),1,padding='same', activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D((2,2)),
  
  tf.keras.layers.Conv2D(256, (3,3),1,padding='same', activation='relu'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D((2,2)),
  
  tf.keras.layers.Flatten(),

  tf.keras.layers.Dense(512, activation='relu'),
  tf.keras.layers.Dense(num_classes,activation='softmax')
])

# %%
model.compile(
  optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=0.001),
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=False),
  metrics=['accuracy'])

# %%
model.build(input_shape=(None,img_height,img_width,3))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  resizing (Resizing)         (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 64)      1792
#
#  batch_normalization (BatchN  (None, 128, 128, 64)     256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 64, 64, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_2 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 512)               8389120
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 8,914,954
# Trainable params: 8,913,802
# Non-trainable params: 1,152
# _________________________________________________________________

# %% [markdown]
# ### Saving model logs to directory

# %%
log_dir = 'logs'

# %%
tensorflow_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

# %% [markdown]
# ### Early stopping
# stopping the model if val_loss after 5th epoch is not decreasing 4 epochs in a row

# %%
early_stopping= EarlyStopping(monitor='val_loss', patience=4,start_from_epoch=5,restore_best_weights=True)

# %% [markdown]
# ### ReduceLROnPlateau

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=3, min_lr=0.00001,mode='min')

# %% [markdown]
# # Model training

# %%
hist = model.fit(
  train,
  validation_data=val,
  epochs=30,
  callbacks=[tensorflow_callback,early_stopping,reduce_lr],
  verbose=1
)
# Out:
# Epoch 1/30
# 2023-03-13 16:30:49.967285: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - ETA: 0s - loss: 4.7010 - accuracy: 0.6507
# 2023-03-13 16:31:23.627213: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 153/153 [==============================] - 37s 241ms/step - loss: 4.7010 - accuracy: 0.6507 - val_loss: 4.7322 - val_accuracy: 0.0959 - lr: 0.0010
# Epoch 2/30
# 153/153 [==============================] - 34s 224ms/step - loss: 1.0257 - accuracy: 0.8037 - val_loss: 4.9085 - val_accuracy: 0.1655 - lr: 0.0010
# Epoch 3/30
# 153/153 [==============================] - 34s 224ms/step - loss: 0.5119 - accuracy: 0.8660 - val_loss: 1.9184 - val_accuracy: 0.5014 - lr: 0.0010
# Epoch 4/30
# 153/153 [==============================] - 34s 224ms/step - loss: 0.3269 - accuracy: 0.8977 - val_loss: 1.1340 - val_accuracy: 0.7379 - lr: 0.0010
# Epoch 5/30
# 153/153 [==============================] - 34s 220ms/step - loss: 0.2987 - accuracy: 0.9142 - val_loss: 0.9568 - val_accuracy: 0.7848 - lr: 0.0010
# Epoch 6/30
# 153/153 [==============================] - 33s 218ms/step - loss: 0.2470 - accuracy: 0.9324 - val_loss: 1.3979 - val_accuracy: 0.7933 - lr: 0.0010
# Epoch 7/30
# 153/153 [==============================] - 35s 227ms/step - loss: 0.2347 - accuracy: 0.9314 - val_loss: 1.0487 - val_accuracy: 0.7983 - lr: 0.0010
# Epoch 8/30
# 153/153 [==============================] - 35s 228ms/step - loss: 0.1917 - accuracy: 0.9438 - val_loss: 1.3427 - val_accuracy: 0.7784 - lr: 0.0010
# Epoch 9/30
# 153/153 [==============================] - 34s 220ms/step - loss: 0.0895 - accuracy: 0.9726 - val_loss: 0.5253 - val_accuracy: 0.9027 - lr: 5.0000e-04
# Epoch 10/30
# 153/153 [==============================] - 34s 223ms/step - loss: 0.0317 - accuracy: 0.9908 - val_loss: 0.4372 - val_accuracy: 0.9205 - lr: 5.0000e-04
# Epoch 11/30
# 153/153 [==============================] - 33s 218ms/step - loss: 0.0154 - accuracy: 0.9971 - val_loss: 0.3935 - val_accuracy: 0.9240 - lr: 5.0000e-04
# Epoch 12/30
# 153/153 [==============================] - 34s 223ms/step - loss: 0.0090 - accuracy: 0.9980 - val_loss: 0.3817 - val_accuracy: 0.9290 - lr: 5.0000e-04
# Epoch 13/30
# 153/153 [==============================] - 34s 223ms/step - loss: 0.0056 - accuracy: 0.9992 - val_loss: 0.3668 - val_accuracy: 0.9311 - lr: 5.0000e-04
# Epoch 14/30
# 153/153 [==============================] - 34s 224ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.3602 - val_accuracy: 0.9318 - lr: 5.0000e-04
# Epoch 15/30
# 153/153 [==============================] - 34s 222ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.3629 - val_accuracy: 0.9311 - lr: 5.0000e-04
# Epoch 16/30
# 153/153 [==============================] - 35s 226ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.3748 - val_accuracy: 0.9311 - lr: 5.0000e-04
# Epoch 17/30
# 153/153 [==============================] - 34s 225ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3766 - val_accuracy: 0.9332 - lr: 5.0000e-04
# Epoch 18/30
# 153/153 [==============================] - 34s 224ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3701 - val_accuracy: 0.9339 - lr: 2.5000e-04

# %% [markdown]
# ### Plotting training loss and validation loss

# %%
fig = plt.figure()

plt.figure(figsize=(5, 3))

plt.plot(hist.history['loss'],color='teal',label='loss')
plt.plot(hist.history['val_loss'],color='orange',label='val_loss')

plt.suptitle('Loss',fontsize=14)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Plotting training accuracy and validation accuracy

# %%
fig = plt.figure()
plt.figure(figsize=(5, 3))

plt.plot(hist.history['accuracy'],color='teal',label='accuracy')
plt.plot(hist.history['val_accuracy'],color='orange',label='val_accuracy')

plt.suptitle('Accuracy',fontsize=14)
plt.legend(loc='lower right')
plt.show()

# %%
model.evaluate(test)
# Out:
# 22/22 [==============================] - 3s 57ms/step - loss: 0.3418 - accuracy: 0.9353
# [0.34181758761405945, 0.9353448152542114]

# %% [markdown]
# # Confusion Matrix
# since confusion matrix cannot handle batches they are unpacked into the arrays

# %%
predcs = []
labels = []
batches=[]

for batch in test.as_numpy_iterator():
    batches.append(batch)
    
for next_batch in batches:
    for pred in next_batch[0]:
        predcs.append(pred)
    for label in next_batch[1]:
        labels.append(label)

predcs = np.asarray(predcs)
labels = np.asarray(labels)

# %%
y_pred = np.array(model.predict(predcs))
y_true = np.array(labels)
# Out:
#  3/22 [===>..........................] - ETA: 0s
# 2023-03-13 16:41:10.610617: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 1s 62ms/step

# %%
pred_max = []
for x in y_pred:
    pred_max.append(np.argmax(x))

y_pred = pred_max

# %%
counter = Counter(y_true)

print('Number of instances per class in the testing set \n')
for label, num in sorted(counter.items()):
    print(f'{class_names[label]}: {num}')
# Out:
# Number of instances per class in the testing set
#
# beach: 72
# chaparral: 67
# circular_farmland: 75
# desert: 64
# forest: 51
# island: 84
# lake: 73
# sea_ice: 71
# snowberg: 68
# terrace: 71

# %%
cm= confusion_matrix(y_true,y_pred,normalize='true')

plt.figure(figsize=(8,8))
plt.title('Confusion matrix of the classifier')
sns.heatmap(cm,
            annot=True, 
            fmt=".2f",
            cmap=sns.color_palette("Blues",12),
            yticklabels=class_names,
            xticklabels=class_names)

plt.xticks(rotation=45)
plt.xlabel('Predicted')
plt.ylabel('True')

plt.show()

# %% [markdown]
# ### Plotting images from testing dataset with predicted labels

# %%
X_test = batches[0][0]
y_test = batches[0][1]

# %%
fig = plt.figure(figsize=(8, 8))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img = normalization_layer(X_test[i])
    fig.add_subplot(rows, columns, i)
    plt.title(class_names[y_pred[i]])
    plt.axis("off")
    plt.imshow(img)
plt.show()
